# %%
import pandas as pd

# %%
toilet = pd.read_csv("toilet_scraped_final.csv")
toilet.head()
# Out:
#   web-scraper-order                      web-scraper-start-url  \
# 0   1647935913-3904  https://www.toilet.org.sg/loomapdirectory
# 1   1647935913-3874  https://www.toilet.org.sg/loomapdirectory
# 2   1647935913-3895  https://www.toilet.org.sg/loomapdirectory
# 3   1647935913-3641  https://www.toilet.org.sg/loomapdirectory
# 4   1647935913-3857  https://www.toilet.org.sg/loomapdirectory
#
#               type                     image_link  \
# 0        Dormitory  Unison Construction Dormitory
# 1      MRT Station             Dakota MRT Station
# 2  Bus Interchange   Bukit  Batok Bus Interchange
# 3  Bus Interchange      Harbourfront Bus Terminal
# 4  Shopping Centre                    Vista Point
#
#                                      image_link-href  \
# 0  https://www.toilet.org.sg/gallery/201/5-star-t...
# 1  https://www.toilet.org.sg/gallery/143/4-star-t...
# 2  https://www.toilet.org.sg/gallery/397/5-star-t...
# 3  https://www.toilet.org.sg/gallery/302/4-star-t...
# 4  https://www.toilet.org.sg/gallery/127/3-star-t...
#
#                                                award  \
# 0  <font color="#F7C709"><i class="fa fa-star"></...
# 1  <font color="#F7C709"><i class="fa fa-star"></...
# 2  <font color="#F7C709"><i class="fa fa-star"></...
# 3  <font color="#F7C709"><i class="fa fa-star"></...
# 4  <font color="#F7C709"><i class="fa fa-star"></...
#
#                                  address                    toilet_name  \
# 0           6 Tuas Basin Link, S(638760)  Unison Construction Dormitory
# 1            201 Airport Road, S(397973)             Dakota MRT Station
# 2     631 Bukit Batok Central, S(650631)   Bukit  Batok Bus Interchange
# 3              4 Seah Im Road, S(099115)      Harbourfront Bus Terminal
# 4  Blk 548 Woodlands Drive 44, S(730548)                    Vista Point
#
#          district_name
# 0  South West District
# 1  South East District
# 2  South West District
# 3     Central District
# 4  North West District

# %%
import requests

API_KEY = 'AIzaSyDhfB61cD1HwRerr6-pDDcnhhzsrLdbnNc'

def getGeoCoord(address):
    params = {
        'key': API_KEY,
        'address': address.replace(' ', '+')
    }

    base_url = 'https://maps.googleapis.com/maps/api/geocode/json?'
    response = requests.get(base_url, params=params)
    data = response.json()
    if data['status'] == 'OK':
        result = data['results'][0]
        location = result['geometry']['location']
        return location['lat'], location['lng']
    else:
        return

toilet['coords'] = toilet['address'].apply(lambda x: getGeoCoord(x))
toilet.head()
# Out:
#   web-scraper-order                      web-scraper-start-url  \
# 0   1647935913-3904  https://www.toilet.org.sg/loomapdirectory
# 1   1647935913-3874  https://www.toilet.org.sg/loomapdirectory
# 2   1647935913-3895  https://www.toilet.org.sg/loomapdirectory
# 3   1647935913-3641  https://www.toilet.org.sg/loomapdirectory
# 4   1647935913-3857  https://www.toilet.org.sg/loomapdirectory
#
#               type                     image_link  \
# 0        Dormitory  Unison Construction Dormitory
# 1      MRT Station             Dakota MRT Station
# 2  Bus Interchange   Bukit  Batok Bus Interchange
# 3  Bus Interchange      Harbourfront Bus Terminal
# 4  Shopping Centre                    Vista Point
#
#                                      image_link-href  \
# 0  https://www.toilet.org.sg/gallery/201/5-star-t...
# 1  https://www.toilet.org.sg/gallery/143/4-star-t...
# 2  https://www.toilet.org.sg/gallery/397/5-star-t...
# 3  https://www.toilet.org.sg/gallery/302/4-star-t...
# 4  https://www.toilet.org.sg/gallery/127/3-star-t...
#
#                                                award  \
# 0  <font color="#F7C709"><i class="fa fa-star"></...
# 1  <font color="#F7C709"><i class="fa fa-star"></...
# 2  <font color="#F7C709"><i class="fa fa-star"></...
# 3  <font color="#F7C709"><i class="fa fa-star"></...
# 4  <font color="#F7C709"><i class="fa fa-star"></...
#
#                                  address                    toilet_name  \
# 0           6 Tuas Basin Link, S(638760)  Unison Construction Dormitory
# 1            201 Airport Road, S(397973)             Dakota MRT Station
# 2     631 Bukit Batok Central, S(650631)   Bukit  Batok Bus Interchange
# 3              4 Seah Im Road, S(099115)      Harbourfront Bus Terminal
# 4  Blk 548 Woodlands Drive 44, S(730548)                    Vista Point
#
#          district_name                    coords
# 0  South West District  (1.3184954, 103.6484818)
# 1  South East District                      None
# 2  South West District  (1.3496816, 103.7512047)
# 3     Central District  (1.2669654, 103.8190449)
# 4  North West District  (1.4313546, 103.7940534)

# %%
toilet.to_csv("toilet_with_coords.csv")

# %%
toilet = pd.read_csv("toilet_with_coords.csv")

# %%
test = toilet[["address", "coords"]]
test
# Out:
#                                    address                    coords
# 0             6 Tuas Basin Link, S(638760)  (1.3184954, 103.6484818)
# 1              201 Airport Road, S(397973)                       NaN
# 2       631 Bukit Batok Central, S(650631)  (1.3496816, 103.7512047)
# 3                4 Seah Im Road, S(099115)  (1.2669654, 103.8190449)
# 4    Blk 548 Woodlands Drive 44, S(730548)  (1.4313546, 103.7940534)
# ..                                     ...                       ...
# 317          70A, Punggol Place, S(828865)  (1.4040984, 103.9022099)
# 318     31 Marina Coastal Drive, S(018988)  (1.2708997, 103.8632543)
# 319        Blk 665 Buffalo Road, S(210665)                       NaN
# 320             90 Pioneer Road, S(639608)  (1.3211893, 103.6486575)
# 321       252 North Bridge Road, S(179103)                       NaN
#
# [322 rows x 2 columns]

# %%
test = toilet[toilet['coords'].isna()][["address", "coords"]]
test
# Out:
#                                                address coords
# 1                          201 Airport Road, S(397973)    NaN
# 26                        2 Bayfront Avenue, S(018972)    NaN
# 49   991 Buangkok Link, Buangkok Square Mall, S(530...    NaN
# 86          Imbiah Express Station, Sentosa, S(099981)    NaN
# 96            5 Lower Kent Ridge Rd, #01-01, S(119074)    NaN
# 134                     12 BedokNorth Drive, S(465492)    NaN
# 138                    31, Bencoolen Street, S(189658)    NaN
# 139                        11 Canberra Road, S(759775)    NaN
# 143                      51 Kranji Crescent, S(728661)    NaN
# 168                   491 River Valley Road, S(248371)    NaN
# 170                       541 Kallang Bahru, S(339355)    NaN
# 175      90 Hougang Avenue 10, Level B1 - 2, S(538766)    NaN
# 177                          7 Cross Street, S(048416)    NaN
# 191                          49 Scotts Road, S(228234)    NaN
# 196                           1 Cashew Road, S(679696)    NaN
# 207               2 Tukang Innovation Grove, S(618305)    NaN
# 239           20 Woodlands North Coast Road, S(737668)    NaN
# 252                      Palawan Beach Walk, S(098038)    NaN
# 260    Blk 399 Yung Sheng Road (Near Party World/NTUC)    NaN
# 264                     14, Kung Chong Road, S(159150)    NaN
# 283                      65 Bras Basah Road, S(189561)    NaN
# 302                           1 Jalan Kukoh, S(161001)    NaN
# 319                    Blk 665 Buffalo Road, S(210665)    NaN
# 321                   252 North Bridge Road, S(179103)    NaN

# %%
toilet.info()
# 7 toilets no image link
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 322 entries, 0 to 321
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             322 non-null    int64
#  1   web-scraper-order      322 non-null    object
#  2   web-scraper-start-url  322 non-null    object
#  3   type                   322 non-null    object
#  4   image_link             315 non-null    object
#  5   image_link-href        315 non-null    object
#  6   award                  322 non-null    object
#  7   address                322 non-null    object
#  8   toilet_name            322 non-null    object
#  9   district_name          322 non-null    object
#  10  coords                 298 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 27.8+ KB

# %%
toilet['district_name'].unique()
# Out:
# array(['South West District', 'South East District', 'Central District',
#        'North West District', 'North East District'], dtype=object)

# %%
def count_star(html):
    return html.count("fa fa-star")

toilet['award_int'] = toilet['award'].apply(lambda x: count_star(x))
toilet.head()
# Out:
#   web-scraper-order                      web-scraper-start-url  \
# 0   1647935913-3904  https://www.toilet.org.sg/loomapdirectory
# 1   1647935913-3874  https://www.toilet.org.sg/loomapdirectory
# 2   1647935913-3895  https://www.toilet.org.sg/loomapdirectory
# 3   1647935913-3641  https://www.toilet.org.sg/loomapdirectory
# 4   1647935913-3857  https://www.toilet.org.sg/loomapdirectory
#
#               type                     image_link  \
# 0        Dormitory  Unison Construction Dormitory
# 1      MRT Station             Dakota MRT Station
# 2  Bus Interchange   Bukit  Batok Bus Interchange
# 3  Bus Interchange      Harbourfront Bus Terminal
# 4  Shopping Centre                    Vista Point
#
#                                      image_link-href  \
# 0  https://www.toilet.org.sg/gallery/201/5-star-t...
# 1  https://www.toilet.org.sg/gallery/143/4-star-t...
# 2  https://www.toilet.org.sg/gallery/397/5-star-t...
# 3  https://www.toilet.org.sg/gallery/302/4-star-t...
# 4  https://www.toilet.org.sg/gallery/127/3-star-t...
#
#                                                award  \
# 0  <font color="#F7C709"><i class="fa fa-star"></...
# 1  <font color="#F7C709"><i class="fa fa-star"></...
# 2  <font color="#F7C709"><i class="fa fa-star"></...
# 3  <font color="#F7C709"><i class="fa fa-star"></...
# 4  <font color="#F7C709"><i class="fa fa-star"></...
#
#                                  address                    toilet_name  \
# 0           6 Tuas Basin Link, S(638760)  Unison Construction Dormitory
# 1            201 Airport Road, S(397973)             Dakota MRT Station
# 2     631 Bukit Batok Central, S(650631)   Bukit  Batok Bus Interchange
# 3              4 Seah Im Road, S(099115)      Harbourfront Bus Terminal
# 4  Blk 548 Woodlands Drive 44, S(730548)                    Vista Point
#
#          district_name  award_int
# 0  South West District          5
# 1  South East District          4
# 2  South West District          5
# 3     Central District          4
# 4  North West District          3

# %%
# drop not useful columns
toilet1 = toilet.drop(columns = ['web-scraper-order', 'web-scraper-start-url', 'image_link', 'award'])
toilet1.head()
# Out:
#               type                                    image_link-href  \
# 0        Dormitory  https://www.toilet.org.sg/gallery/201/5-star-t...
# 1      MRT Station  https://www.toilet.org.sg/gallery/143/4-star-t...
# 2  Bus Interchange  https://www.toilet.org.sg/gallery/397/5-star-t...
# 3  Bus Interchange  https://www.toilet.org.sg/gallery/302/4-star-t...
# 4  Shopping Centre  https://www.toilet.org.sg/gallery/127/3-star-t...
#
#                                  address                    toilet_name  \
# 0           6 Tuas Basin Link, S(638760)  Unison Construction Dormitory
# 1            201 Airport Road, S(397973)             Dakota MRT Station
# 2     631 Bukit Batok Central, S(650631)   Bukit  Batok Bus Interchange
# 3              4 Seah Im Road, S(099115)      Harbourfront Bus Terminal
# 4  Blk 548 Woodlands Drive 44, S(730548)                    Vista Point
#
#          district_name  award_int
# 0  South West District          5
# 1  South East District          4
# 2  South West District          5
# 3     Central District          4
# 4  North West District          3

# %%
toilet1.to_json("toilets.json")

# %%
# Out:
# {'results': [{'address_components': [{'long_name': '6', 'short_name': '6', 'types': ['street_number']}, {'long_name': 'Tuas Basin Link', 'short_name': 'Tuas Basin Link', 'types': ['route']}, {'long_name': 'Tuas', 'short_name': 'Tuas', 'types': ['neighborhood', 'political']}, {'long_name': 'Singapore', 'short_name': 'Singapore', 'types': ['locality', 'political']}, {'long_name': 'Singapore', 'short_name': 'SG', 'types': ['country', 'political']}, {'long_name': '638760', 'short_name': '638760', 'types': ['postal_code']}], 'formatted_address': '6 Tuas Basin Link, Singapore 638760', 'geometry': {'bounds': {'northeast': {'lat': 1.3186864, 'lng': 103.6487633}, 'southwest': {'lat': 1.3181812, 'lng': 103.6482467}}, 'location': {'lat': 1.3184954, 'lng': 103.6484818}, 'location_type': 'ROOFTOP', 'viewport': {'northeast': {'lat': 1.319695930291502, 'lng': 103.6499854302915}, 'southwest': {'lat': 1.316997969708498, 'lng': 103.6472874697085}}}, 'place_id': 'ChIJDc0mA_AF2jERSLTzZosPLuI', 'types': ['premise']}], 'status': 'OK'}
# (1.3184954, 103.6484818)
